# %% [markdown]
# # Phase 03 - Graph Construction
#
# **Goal:** Convert the cleaned IEEE-CIS dataframe into a leakage-safe PyTorch Geometric heterogeneous graph for Phase 04.
#
# This version fixes the main issues before modeling:
#
# - Saves a real `HeteroData` object instead of a custom dictionary.
# - Stores forward and reverse edges as separate heterogeneous relations.
# - Removes label-derived entity features, so validation/test labels cannot leak into node features.
# - Adds train/validation/test masks on transaction nodes.
# - Adds `ProductCD` as an entity node because Phase 02 showed it carries signal.
#
# By the end, Phase 04 can load `hetero_data.pt` directly.

# %% [markdown]
# ## 3.1 - Imports and Load Data
#
# We load the cleaned dataframe from Phase 01 and the selected top V-features from Phase 02. The path helper works both in Colab-style `/content/sample_data` and local `content/sample_data` folders.

# %%
import json
import os
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import train_test_split

try:
    from torch_geometric.data import HeteroData
except ImportError as exc:
    raise ImportError(
        'PyTorch Geometric is required for Phase 03. Install it before running this notebook.'
    ) from exc

warnings.filterwarnings('ignore')

DATA_DIR = Path('/content/sample_data')
if not DATA_DIR.exists():
    DATA_DIR = Path('content/sample_data')

df_path = DATA_DIR / 'df_preprocessed.csv'
features_path = DATA_DIR / 'useful_v_features.json'

df = pd.read_csv(df_path)
with open(features_path, 'r') as f:
    useful_v_features = json.load(f)

print(f'Loaded dataframe  : {df.shape[0]:,} rows x {df.shape[1]} cols')
print(f'Useful V-features : {len(useful_v_features)}')
print(f'Data directory    : {DATA_DIR}')
# Out:
# Loaded dataframe  : 590,540 rows x 434 cols
# Useful V-features : 40
# Data directory    : content\sample_data

# %% [markdown]
# ## 3.2 - Graph Schema Definition
#
# The graph has one transaction node for each dataframe row. Shared categorical entities become their own node types, so transactions can exchange information through common cards, products, addresses, emails, and devices.
#
# Rare entity values are grouped into one `__rare__` node per entity type. This avoids thousands of tiny nodes that add memory cost without much relational signal.

# %%
# Entity columns and their PyG node type names
ENTITY_COLS = {
    'ProductCD':     'product',
    'card1':         'card1',
    'card2':         'card2',
    'card3':         'card3',
    'card4':         'card4',
    'card5':         'card5',
    'card6':         'card6',
    'addr1':         'addr1',
    'addr2':         'addr2',
    'P_emaildomain': 'email_p',
    'R_emaildomain': 'email_r',
    'DeviceType':    'device_type',
    'DeviceInfo':    'device_info',
}

MIN_COUNT_THRESHOLD = 5
RANDOM_STATE = 42

missing_cols = [col for col in ENTITY_COLS if col not in df.columns]
if missing_cols:
    raise ValueError(f'Missing required entity columns: {missing_cols}')

print('Graph schema defined.')
print(f'Entity columns      : {len(ENTITY_COLS)}')
print(f'Node types          : {1 + len(ENTITY_COLS)}')
print(f'Edge relations      : {2 * len(ENTITY_COLS)}')
print(f'Min count threshold : {MIN_COUNT_THRESHOLD}')
# Out:
# Graph schema defined.
# Entity columns      : 13
# Node types          : 14
# Edge relations      : 26
# Min count threshold : 5

# %% [markdown]
# ## 3.3 - Train/Validation/Test Masks
#
# Only transaction nodes have labels. We create boolean masks on the transaction node type so Phase 04 can train and evaluate without mixing splits.
#
# This first split is stratified, which keeps the fraud ratio similar across train, validation, and test. A later production-style experiment can switch to a time-based split using `TransactionDT`.

# %%
labels_np = df['isFraud'].astype(int).values
all_idx = np.arange(len(df))

train_idx, temp_idx = train_test_split(
    all_idx,
    test_size=0.30,
    random_state=RANDOM_STATE,
    stratify=labels_np,
)

val_idx, test_idx = train_test_split(
    temp_idx,
    test_size=0.50,
    random_state=RANDOM_STATE,
    stratify=labels_np[temp_idx],
)

def index_to_mask(indices, size):
    mask = torch.zeros(size, dtype=torch.bool)
    mask[torch.tensor(indices, dtype=torch.long)] = True
    return mask

train_mask = index_to_mask(train_idx, len(df))
val_mask = index_to_mask(val_idx, len(df))
test_mask = index_to_mask(test_idx, len(df))

for name, mask in [('train', train_mask), ('val', val_mask), ('test', test_mask)]:
    split_y = labels_np[mask.numpy()]
    print(f'{name:<5} nodes: {mask.sum().item():>8,} | fraud rate: {split_y.mean() * 100:>5.2f}%')
# Out:
# train nodes:  413,378 | fraud rate:  3.50%
# val   nodes:   88,581 | fraud rate:  3.50%
# test  nodes:   88,581 | fraud rate:  3.50%

# %% [markdown]
# ## 3.4 - Build Entity-to-Index Mappings
#
# For each entity column, each frequent unique value gets a node index. Values below the frequency threshold map to the entity type's `__rare__` node.

# %%
entity_mappings = {}
entity_num_nodes = {}

for col in ENTITY_COLS:
    value_counts = df[col].value_counts(dropna=False)
    frequent_values = value_counts[value_counts >= MIN_COUNT_THRESHOLD].index.tolist()

    mapping = {value: idx for idx, value in enumerate(frequent_values)}
    rare_idx = len(frequent_values)
    mapping['__rare__'] = rare_idx

    entity_mappings[col] = mapping
    entity_num_nodes[col] = rare_idx + 1

print(f'{"Column":<20} {"Frequent Nodes":>15} {"Rare Values":>12} {"Total Nodes":>12}')
print('-' * 64)
for col in ENTITY_COLS:
    n_total = entity_num_nodes[col]
    n_frequent = n_total - 1
    n_rare_values = int((df[col].value_counts(dropna=False) < MIN_COUNT_THRESHOLD).sum())
    print(f'{col:<20} {n_frequent:>15,} {n_rare_values:>12,} {n_total:>12,}')
# Out:
# Column                Frequent Nodes  Rare Values  Total Nodes
# ----------------------------------------------------------------
# ProductCD                          5            0            6
# card1                          6,512        7,041        6,513
# card2                            500            0          501
# card3                             76           38           77
# card4                              5            0            6
# card5                             76           43           77
# card6                              5            0            6
# addr1                            133          199          134
# addr2                             30           44           31
# P_emaildomain                     60            0           61
# R_emaildomain                     61            0           62
# DeviceType                         3            0            4
# DeviceInfo                       888          899          889

# %% [markdown]
# ## 3.5 - Build Transaction Node Features
#
# Transaction nodes get the top 40 V-features from Phase 02, normalized transaction amount, and normalized time features.
#
# We avoid feeding raw `TransactionDT` directly because its scale can be very large. Instead, we use:
#
# - `TransactionDT_norm`: standardized elapsed time
# - `hour_sin` and `hour_cos`: cyclic hour-of-day signal
# - `day_norm`: standardized elapsed day

# %%
dt = df['TransactionDT'].astype(np.float32).values
hour = ((dt % (24 * 3600)) / 3600.0).astype(np.float32)
day = np.floor(dt / (24 * 3600)).astype(np.float32)

df['TransactionDT_norm'] = ((dt - dt.mean()) / (dt.std() + 1e-8)).astype(np.float32)
df['hour_sin'] = np.sin(2 * np.pi * hour / 24).astype(np.float32)
df['hour_cos'] = np.cos(2 * np.pi * hour / 24).astype(np.float32)
df['day_norm'] = ((day - day.mean()) / (day.std() + 1e-8)).astype(np.float32)

transaction_feature_cols = useful_v_features + [
    'TransactionAmt',
    'TransactionDT_norm',
    'hour_sin',
    'hour_cos',
    'day_norm',
]

missing_features = [col for col in transaction_feature_cols if col not in df.columns]
if missing_features:
    raise ValueError(f'Missing transaction feature columns: {missing_features}')

transaction_features = df[transaction_feature_cols].values.astype(np.float32)
x_transaction = torch.tensor(transaction_features, dtype=torch.float)
y = torch.tensor(labels_np, dtype=torch.long)

print(f'Transaction feature matrix : {tuple(x_transaction.shape)}')
print(f'Features per transaction   : {x_transaction.shape[1]}')
print(f'Labels vector              : {tuple(y.shape)}')
print(f'Fraud: {y.sum().item():,} | Legitimate: {(y == 0).sum().item():,}')
# Out:
# Transaction feature matrix : (590540, 45)
# Features per transaction   : 45
# Labels vector              : (590540,)
# Fraud: 20,663 | Legitimate: 569,877

# %% [markdown]
# ## 3.6 - Build Leakage-Safe Entity Node Features
#
# Entity nodes must not use validation/test labels as features. The previous version used fraud degree and fraud rate, which can leak answers into the model.
#
# This version uses only structural features:
#
# - normalized degree
# - log-normalized degree
#
# These tell the model how common an entity is without revealing fraud labels.

# %%
entity_features = {}
entity_node_indices_by_col = {}

for col, node_type in ENTITY_COLS.items():
    mapping = entity_mappings[col]
    rare_idx = mapping['__rare__']
    n_nodes = entity_num_nodes[col]

    entity_node_indices = df[col].map(lambda value: mapping.get(value, rare_idx)).values.astype(np.int64)
    entity_node_indices_by_col[col] = entity_node_indices

    degree = np.bincount(entity_node_indices, minlength=n_nodes).astype(np.float32)
    max_degree = degree.max() if degree.max() > 0 else 1.0

    degree_norm = degree / max_degree
    log_degree = np.log1p(degree) / np.log1p(max_degree)

    feat_matrix = np.stack([degree_norm, log_degree], axis=1).astype(np.float32)
    entity_features[col] = torch.tensor(feat_matrix, dtype=torch.float)

print(f'{"Entity Column":<20} {"Node Type":<15} {"Feature Shape":>18}')
print('-' * 58)
for col, node_type in ENTITY_COLS.items():
    print(f'{col:<20} {node_type:<15} {str(tuple(entity_features[col].shape)):>18}')
# Out:
# Entity Column        Node Type            Feature Shape
# ----------------------------------------------------------
# ProductCD            product                     (6, 2)
# card1                card1                    (6513, 2)
# card2                card2                     (501, 2)
# card3                card3                      (77, 2)
# card4                card4                       (6, 2)
# card5                card5                      (77, 2)
# card6                card6                       (6, 2)
# addr1                addr1                     (134, 2)
# addr2                addr2                      (31, 2)
# P_emaildomain        email_p                    (61, 2)
# R_emaildomain        email_r                    (62, 2)
# DeviceType           device_type                 (4, 2)
# DeviceInfo           device_info               (889, 2)

# %% [markdown]
# ## 3.7 - Build PyG HeteroData
#
# We now create a real PyTorch Geometric `HeteroData` object.
#
# Each entity relation is stored twice:
#
# - `transaction -> entity`
# - `entity -> transaction`
#
# Keeping these as separate relations is the clean PyG format for heterogeneous message passing.

# %%
data = HeteroData()

# Transaction node store
data['transaction'].x = x_transaction
data['transaction'].y = y
data['transaction'].train_mask = train_mask
data['transaction'].val_mask = val_mask
data['transaction'].test_mask = test_mask

# Entity node stores
for col, node_type in ENTITY_COLS.items():
    data[node_type].x = entity_features[col]

transaction_node_indices = torch.arange(len(df), dtype=torch.long)

# Edge stores: transaction -> entity and entity -> transaction
for col, node_type in ENTITY_COLS.items():
    entity_node_indices = torch.tensor(entity_node_indices_by_col[col], dtype=torch.long)

    edge_index_fwd = torch.stack([transaction_node_indices, entity_node_indices], dim=0)
    edge_index_rev = torch.stack([entity_node_indices, transaction_node_indices], dim=0)

    data['transaction', f'has_{node_type}', node_type].edge_index = edge_index_fwd
    data[node_type, f'rev_has_{node_type}', 'transaction'].edge_index = edge_index_rev

# Lightweight metadata for Phase 04 and inference
data.graph_info = {
    'entity_cols': dict(ENTITY_COLS),
    'transaction_feature_cols': transaction_feature_cols,
    'min_count_threshold': MIN_COUNT_THRESHOLD,
    'random_state': RANDOM_STATE,
    'split': {'train': 0.70, 'val': 0.15, 'test': 0.15},
    'entity_feature_cols': ['degree_norm', 'log_degree'],
}
data.entity_mappings = entity_mappings

print(data)
print()
print('Node types:', data.node_types)
print('Edge types:', len(data.edge_types))
# Out:
# HeteroData(
#   graph_info={
#     entity_cols={
#       ProductCD='product',
#       card1='card1',
#       card2='card2',
#       card3='card3',
#       card4='card4',
#       card5='card5',
#       card6='card6',
#       addr1='addr1',
#       addr2='addr2',
#       P_emaildomain='email_p',
#       R_emaildomain='email_r',
#       DeviceType='device_type',
#       DeviceInfo='device_info',
#     },
#     transaction_feature_cols=[45],
#     min_count_threshold=5,
#     random_state=42,
#     split={
#       train=0.7,
#       val=0.15,
#       test=0.15,
#     },
#     entity_feature_cols=[2],
#   },
#   entity_mappings={
#     ProductCD={
#       4=0,
#       0=1,
#       2=2,
#       1=3,
#       3=4,
#       __rare__=5,
#     },
#     card1={
#       7919=0,
#       9500=1,
#       15885=2,
#       17188=3,
#       15066=4,
#       12695=5,
#       12544=6,
#       6019=7,
#       2803=8,
#       7585=9,
#       10616=10,
#       12839=11,
#       3154=12,
#       2616=13,
# ...

# %% [markdown]
# ## 3.8 - Validation
#
# Before saving, we validate graph structure, mask coverage, edge bounds, and feature tensors.

# %%
checks = {}

checks['Transaction features shape correct'] = (
    data['transaction'].x.shape == (len(df), len(transaction_feature_cols))
)
checks['Labels length matches transactions'] = (len(data['transaction'].y) == len(df))
checks['Masks are exhaustive'] = (
    (train_mask | val_mask | test_mask).sum().item() == len(df)
)
checks['Masks are mutually exclusive'] = (
    not (train_mask & val_mask).any().item()
    and not (train_mask & test_mask).any().item()
    and not (val_mask & test_mask).any().item()
)
checks['Labels are binary'] = (set(data['transaction'].y.unique().tolist()) == {0, 1})
checks['No NaN in node features'] = all(
    not torch.isnan(data[node_type].x).any().item()
    for node_type in data.node_types
)
checks['Entity features are leakage-safe shape'] = all(
    data[node_type].x.shape[1] == 2
    for node_type in ENTITY_COLS.values()
)
checks['Forward edge counts are correct'] = all(
    data['transaction', f'has_{node_type}', node_type].edge_index.shape == (2, len(df))
    for node_type in ENTITY_COLS.values()
)
checks['Reverse edge counts are correct'] = all(
    data[node_type, f'rev_has_{node_type}', 'transaction'].edge_index.shape == (2, len(df))
    for node_type in ENTITY_COLS.values()
)
checks['Entity edge indices in range'] = all(
    data['transaction', f'has_{node_type}', node_type].edge_index[1].max().item() < entity_num_nodes[col]
    for col, node_type in ENTITY_COLS.items()
)
checks['Transaction edge indices in range'] = all(
    data['transaction', f'has_{node_type}', node_type].edge_index[0].max().item() < len(df)
    and data[node_type, f'rev_has_{node_type}', 'transaction'].edge_index[1].max().item() < len(df)
    for node_type in ENTITY_COLS.values()
)

try:
    pyg_validation_passed = bool(data.validate(raise_on_error=False))
except Exception:
    pyg_validation_passed = False
checks['PyG validation passed'] = pyg_validation_passed

all_pass = True
for name, result in checks.items():
    status = 'PASS' if result else 'FAIL'
    print(f'{status:<4}  {name}')
    if not result:
        all_pass = False

print()
if all_pass:
    print('All checks passed. Graph is ready for Phase 04.')
else:
    print('Some checks failed. Fix them before training.')
# Out:
# PASS  Transaction features shape correct
# PASS  Labels length matches transactions
# PASS  Masks are exhaustive
# PASS  Masks are mutually exclusive
# PASS  Labels are binary
# PASS  No NaN in node features
# PASS  Entity features are leakage-safe shape
# PASS  Forward edge counts are correct
# PASS  Reverse edge counts are correct
# PASS  Entity edge indices in range
# PASS  Transaction edge indices in range
# PASS  PyG validation passed
#
# All checks passed. Graph is ready for Phase 04.

# %% [markdown]
# ## 3.9 - Save the Graph
#
# We save the PyG object as `hetero_data.pt`. Phase 04 should load this file directly with `torch.load`.

# %%
if all_pass:
    save_path = DATA_DIR / 'hetero_data.pt'
    torch.save(data, save_path)
    file_size_mb = os.path.getsize(save_path) / (1024 * 1024)

    print(f'Graph saved to: {save_path}')
    print(f'File size     : {file_size_mb:.1f} MB')
    print()
    print('Summary:')
    print(f'  Node types       : {len(data.node_types)}')
    print(f'  Edge relations   : {len(data.edge_types)}')
    print(f'  Transaction nodes: {data["transaction"].num_nodes:,}')
    print(f'  Transaction dims : {data["transaction"].x.shape[1]}')
    print(f'  Entity dims      : 2')
    print()
    print('Phase 03 complete. Next: Phase 04 - GNN Model.')
else:
    print('Graph not saved. Fix validation errors first.')
# Out:
# Graph saved to: content\sample_data\hetero_data.pt
# File size     : 342.0 MB
#
# Summary:
#   Node types       : 14
#   Edge relations   : 26
#   Transaction nodes: 590,540
#   Transaction dims : 45
#   Entity dims      : 2
#
# Phase 03 complete. Next: Phase 04 - GNN Model.
